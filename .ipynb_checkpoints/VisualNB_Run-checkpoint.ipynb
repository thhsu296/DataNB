# %% [markdown]
# # Visualization of DataNB

# %%
from visualNB import VisualNB
import matplotlib.pyplot as plt

# %% [markdown]
# ## Compare Zones within New Brunswick

# %%
vis = VisualNB()
vis.load(fileName='dataNB.csv')

# %%
vis.plot(start='2020-01-01', end='2021-12-31')
# Out:
# NB: from 2020-03-25 to 2021-02-08

# %% [markdown]
# ## Compare New Brunswick with British Columbia

# %%
# vis.download_BC(url='http://www.bccdc.ca/Health-Info-Site/Documents/BCCDC_COVID19_Dashboard_Case_Details.csv')
vis.load_BC(fileName='BCCDC_COVID19_Dashboard_Case_Details.csv')

# %%
vis.plot_BC(start='2020-01-01', end='2021-12-31')
# Out:
# From 2020-01-29 to 2021-03-03
